# %% [markdown]
# <a href="https://colab.research.google.com/github/sadewa0909/PCVK_Genap_2021/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placekitten.com/800/571"]

for url in urls:
  image = io.imread(url)  #readimage
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB) #convert color to RGB
  final_frame = cv.hconcat((image, image_2))  #concatenate image
  cv2_imshow(final_frame) #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276 at 0x7F392C6F9C88>
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F392C6F9E48>
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F392C6F9C18>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286 at 0x7F3922027F28>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F392201EE80>

# %%
Jawaban Pertanyaan :
1. Sesuai dengan modul praktikum ini menggunakan Bahasa permrograman python yang menggunakan interpreter yang cocok dengan Google Colab
2. NumPy sebuah library Python yang fokus pada scientific computing. Pandas sebuah library Python yang fokus untuk proses analisis data seperti manipulasi data, persiapan data, dan pembersihan data. Matplotlib sebuah library Python yang fokus pada visualisasi data seperti membuat plot grafik.
3. Mengubah ukuran gambar menjadi setengah ukuran
4. kegunaannya yaitu untuk membuat sebuah garis horizontal
5. Resolusi ditentukan dari jumlah dan kumpulan pixel yang membentuk image. Resolusi penentu kualitas gambar digital. Karena resolusi berbanding lurus dengan sebuah kualitas gambar.

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range (tinggi):
  image_3[y, int ((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F3922035128>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

cv.line(image_3, (0,0), (lebar, tinggi), (255,255,255), 2)
cv.line(image_3, (lebar,0), (0, tinggi), (255,255,255), 2)

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F3922027240>
